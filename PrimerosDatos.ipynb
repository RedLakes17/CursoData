# %%
import pandas as pd 

dat1 = pd.read_csv('datos_muestra_1.csv')
dat1.head()
# Out:
# C:\Users\Antonio Rojas\AppData\Local\Temp\ipykernel_9152\1496199601.py:3: DtypeWarning: Columns (2,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dat1 = pd.read_csv('datos_muestra_1.csv')
#    edad  minutos                        monto_de_apoyo  horas  ent_regis  \
# 0  4069       27                                   NaN     16        1.0
# 1  4093        0                              31446.48      6        NaN
# 2  4092       30                              65673.63     16        1.0
# 3  4047       58  Sistema Tecnológico de Jalisco, A.C.      3        NaN
# 4  4040       50                              30254.04      6        1.0
#
#    mun_regis  ent_resid  mun_resid  ent_ocurr  mun_ocurr  ... grupo  lengua  \
# 0          1          1          1        NaN          1  ...     7     2.0
# 1          1          1          1        NaN          1  ...     8     NaN
# 2          1          1          1        NaN          1  ...     2     NaN
# ...

# %%
'''Ocupmos limpiar los datos'''

#Clasificacion de variables. Continuas, discretas, fecha, texto

continuas = ['monto_de_apoyo']
discretas = ['edad', 'minutos', 'horas', 'ent_regis', 'mun_regis', 'ent_resid', 'mun_resid', 'ent_ocurr', 'mun_ocurr', 'sexo', 'ocupacion', 'edo_civil',
             'lugar_ocur', 'sitio_ocur', 'nacilnalidad', 'grupo', 'lengua', 'clave', 'escolaridad']
fecha = ['fecha_nac', 'fecha_ocurr']
texto = ['programa_fondo', 'nomobre_del_proyecto', 'nombre_del_beneficiario']


continuas_new = ['c_' + x for x in continuas]
discretas_new = ['c_' + x for x in discretas]
fecha_new = ['c_' + x for x in fecha]
texto_new = ['c_' + x for x in texto]
